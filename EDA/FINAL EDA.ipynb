# %% [markdown]
# ## Aspiring Mind Employment Outcome 2015

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('aspiring_minds_employability_outcomes_2015.xlsx')
df.sample(5)
# Out:
#      Unnamed: 0       ID  Salary        DOJ                  DOL  \
# 3977      train   217036  415000 2011-09-01              present
# 1596      train   103323  410000 2010-12-01  2014-03-01 00:00:00
# 212       train  1173129  240000 2014-06-01  2015-04-01 00:00:00
# 1170      train  1148365  105000 2013-08-01  2014-08-01 00:00:00
# 310       train   340877  470000 2012-09-01  2015-04-01 00:00:00
#
#                      Designation    JobCity Gender        DOB  10percentage  \
# 3977           software engineer     Mumbai      m 1990-02-27         62.00
# 1596  delivery software engineer  Bangalore      m 1989-07-12         82.00
# 212               sales engineer  Bhagalpur      m 1990-02-18         79.28
# 1170   software engineer trainee         -1      m 1991-12-25         65.00
# 310            asp.net developer      Noida      f 1991-09-14         70.00
#
#           10board  12graduation  12percentage      12board  CollegeID  \
# 3977            0          2007         61.00            0       4948
# 1596            0          2006         85.00            0        940
# 212   state board          2008         68.55  state board      13517
# 1170  state board          2009         75.60  state board       6904
# 310             0          2007         65.00            0         12
#
#       CollegeTier       Degree          Specialization  collegeGPA  \
# 3977            2  B.Tech/B.E.  information technology       60.00
# 1596            2  B.Tech/B.E.    computer engineering       77.00
# 212             2  B.Tech/B.E.  mechanical engineering       79.75
# 1170            2  B.Tech/B.E.  information technology       62.00
# 310             2  B.Tech/B.E.  information technology       78.00
#
#       CollegeCityID  CollegeCityTier CollegeState  GraduationYear  English  \
# 3977           4948                1    Rajasthan            2011      535
# 1596            940                1   Tamil Nadu            2010      565
# 212           13517                0   Tamil Nadu            2013      615
# 1170           6904                1   Tamil Nadu            2013      350
# 310              12                1        Delhi            2012      495
#
#       Logical  Quant    Domain  ComputerProgramming  ElectronicsAndSemicon  \
# 3977      385    335  0.342315                  365                     -1
# 1596      465    535  0.635979                  445                     -1
# 212       640    545  0.909152                   -1                     -1
# 1170      480    465  0.450877                  395                     -1
# 310       545    445  0.864685                  525                     -1
#
#       ComputerScience  MechanicalEngg  ElectricalEngg  TelecomEngg  CivilEngg  \
# 3977               -1              -1              -1           -1         -1
# 1596               -1              -1              -1           -1         -1
# 212                -1              -1              -1           -1         -1
# 1170               -1              -1              -1           -1         -1
# 310                -1              -1              -1           -1         -1
#
#       conscientiousness  agreeableness  extraversion  nueroticism  \
# 3977            -1.9629        -0.2793       -0.3440      0.53230
# 1596            -2.5811        -0.7473        0.9623      1.82490
# 212              1.1336         1.2114       -1.5270     -0.99500
# 1170            -2.7443        -2.4516       -2.4491     -0.61470
# 310              0.8192        -0.9033       -1.3599     -0.87777
#
#       openess_to_experience
# 3977                -0.1295
# 1596                 0.8183
# 212                  0.8637
# 1170                -3.7350
# 310                 -0.6035

# %%
df.head()
# Out:
#   Unnamed: 0      ID   Salary        DOJ                  DOL  \
# 0      train  203097   420000 2012-06-01              present
# 1      train  579905   500000 2013-09-01              present
# 2      train  810601   325000 2014-06-01              present
# 3      train  267447  1100000 2011-07-01              present
# 4      train  343523   200000 2014-03-01  2015-03-01 00:00:00
#
#                 Designation    JobCity Gender        DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f 1990-02-19          84.3
# 1         assistant manager     Indore      m 1989-10-04          85.4
# 2          systems engineer    Chennai      f 1992-08-03          85.0
# 3  senior software engineer    Gurgaon      m 1989-12-05          85.6
# 4                       get    Manesar      m 1991-02-27          78.0
#
#                           10board  12graduation  12percentage  \
# 0  board ofsecondary education,ap          2007          95.8
# 1                            cbse          2007          85.0
# 2                            cbse          2010          68.2
# 3                            cbse          2007          83.6
# 4                            cbse          2008          76.8
#
#                               12board  CollegeID  CollegeTier       Degree  \
# 0  board of intermediate education,ap       1141            2  B.Tech/B.E.
# 1                                cbse       5807            2  B.Tech/B.E.
# 2                                cbse         64            2  B.Tech/B.E.
# 3                                cbse       6920            1  B.Tech/B.E.
# 4                                cbse      11368            2  B.Tech/B.E.
#
#                               Specialization  collegeGPA  CollegeCityID  \
# 0                       computer engineering       78.00           1141
# 1  electronics and communication engineering       70.06           5807
# 2                     information technology       70.00             64
# 3                       computer engineering       74.64           6920
# 4  electronics and communication engineering       73.90          11368
#
#    CollegeCityTier    CollegeState  GraduationYear  English  Logical  Quant  \
# 0                0  Andhra Pradesh            2011      515      585    525
# 1                0  Madhya Pradesh            2012      695      610    780
# 2                0   Uttar Pradesh            2014      615      545    370
# 3                1           Delhi            2011      635      585    625
# 4                0   Uttar Pradesh            2012      545      625    465
#
#      Domain  ComputerProgramming  ElectronicsAndSemicon  ComputerScience  \
# 0  0.635979                  445                     -1               -1
# 1  0.960603                   -1                    466               -1
# 2  0.450877                  395                     -1               -1
# 3  0.974396                  615                     -1               -1
# 4  0.124502                   -1                    233               -1
#
#    MechanicalEngg  ElectricalEngg  TelecomEngg  CivilEngg  conscientiousness  \
# 0              -1              -1           -1         -1             0.9737
# 1              -1              -1           -1         -1            -0.7335
# 2              -1              -1           -1         -1             0.2718
# 3              -1              -1           -1         -1             0.0464
# 4              -1              -1           -1         -1            -0.8810
#
#    agreeableness  extraversion  nueroticism  openess_to_experience
# 0         0.8128        0.5269      1.35490                -0.4455
# 1         0.3789        1.2396     -0.10760                 0.8637
# 2         1.7109        0.1637     -0.86820                 0.6721
# 3         0.3448       -0.3440     -0.40780                -0.9194
# 4        -0.2793       -1.0697      0.09163                -0.1295

# %%
df.shape
# Out:
# (3998, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3998 non-null   object
#  1   ID                     3998 non-null   int64
#  2   Salary                 3998 non-null   int64
#  3   DOJ                    3998 non-null   datetime64[ns]
#  4   DOL                    3998 non-null   object
#  5   Designation            3998 non-null   object
#  6   JobCity                3998 non-null   object
#  7   Gender                 3998 non-null   object
#  8   DOB                    3998 non-null   datetime64[ns]
#  9   10percentage           3998 non-null   float64
#  10  10board                3998 non-null   object
#  11  12graduation           3998 non-null   int64
#  12  12percentage           3998 non-null   float64
#  13  12board                3998 non-null   object
#  14  CollegeID              3998 non-null   int64
#  15  CollegeTier            3998 non-null   int64
#  16  Degree                 3998 non-null   object
#  17  Specialization         3998 non-null   object
#  18  collegeGPA             3998 non-null   float64
#  19  CollegeCityID          3998 non-null   int64
#  20  CollegeCityTier        3998 non-null   int64
#  21  CollegeState           3998 non-null   object
#  22  GraduationYear         3998 non-null   int64
#  23  English                3998 non-null   int64
#  24  Logical                3998 non-null   int64
#  25  Quant                  3998 non-null   int64
#  26  Domain                 3998 non-null   float64
#  27  ComputerProgramming    3998 non-null   int64
#  28  ElectronicsAndSemicon  3998 non-null   int64
#  29  ComputerScience        3998 non-null   int64
#  30  MechanicalEngg         3998 non-null   int64
#  31  ElectricalEngg         3998 non-null   int64
#  32  TelecomEngg            3998 non-null   int64
#  33  CivilEngg              3998 non-null   int64
#  34  conscientiousness      3998 non-null   float64
#  35  agreeableness          3998 non-null   float64
#  36  extraversion           3998 non-null   float64
#  37  nueroticism            3998 non-null   float64
#  38  openess_to_experience  3998 non-null   float64
# dtypes: datetime64[ns](2), float64(9), int64(18), object(10)
# memory usage: 1.2+ MB

# %%
df.drop(columns=['ID','Unnamed: 0'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (3998, 37)

# %%
np.round(df.describe().T)
# Out:
#                         count      mean       std      min       25%  \
# Salary                 3998.0  307700.0  212737.0  35000.0  180000.0
# 10percentage           3998.0      78.0      10.0     43.0      72.0
# 12graduation           3998.0    2008.0       2.0   1995.0    2007.0
# 12percentage           3998.0      74.0      11.0     40.0      66.0
# CollegeID              3998.0    5157.0    4802.0      2.0     494.0
# CollegeTier            3998.0       2.0       0.0      1.0       2.0
# collegeGPA             3998.0      71.0       8.0      6.0      66.0
# CollegeCityID          3998.0    5157.0    4802.0      2.0     494.0
# CollegeCityTier        3998.0       0.0       0.0      0.0       0.0
# GraduationYear         3998.0    2012.0      32.0      0.0    2012.0
# English                3998.0     502.0     105.0    180.0     425.0
# Logical                3998.0     502.0      87.0    195.0     445.0
# Quant                  3998.0     513.0     122.0    120.0     430.0
# Domain                 3998.0       1.0       0.0     -1.0       0.0
# ComputerProgramming    3998.0     353.0     205.0     -1.0     295.0
# ElectronicsAndSemicon  3998.0      95.0     158.0     -1.0      -1.0
# ComputerScience        3998.0      91.0     175.0     -1.0      -1.0
# MechanicalEngg         3998.0      23.0      98.0     -1.0      -1.0
# ElectricalEngg         3998.0      16.0      88.0     -1.0      -1.0
# TelecomEngg            3998.0      32.0     105.0     -1.0      -1.0
# CivilEngg              3998.0       3.0      37.0     -1.0      -1.0
# conscientiousness      3998.0      -0.0       1.0     -4.0      -1.0
# agreeableness          3998.0       0.0       1.0     -6.0      -0.0
# extraversion           3998.0       0.0       1.0     -5.0      -1.0
# nueroticism            3998.0      -0.0       1.0     -3.0      -1.0
# openess_to_experience  3998.0      -0.0       1.0     -7.0      -1.0
#
#                             50%       75%        max
# Salary                 300000.0  370000.0  4000000.0
# 10percentage               79.0      86.0       98.0
# 12graduation             2008.0    2009.0     2013.0
# 12percentage               74.0      83.0       99.0
# CollegeID                3879.0    8818.0    18409.0
# CollegeTier                 2.0       2.0        2.0
# collegeGPA                 72.0      76.0      100.0
# CollegeCityID            3879.0    8818.0    18409.0
# CollegeCityTier             0.0       1.0        1.0
# GraduationYear           2013.0    2014.0     2017.0
# English                   500.0     570.0      875.0
# Logical                   505.0     565.0      795.0
# Quant                     515.0     595.0      900.0
# Domain                      1.0       1.0        1.0
# ComputerProgramming       415.0     495.0      840.0
# ElectronicsAndSemicon      -1.0     233.0      612.0
# ComputerScience            -1.0      -1.0      715.0
# MechanicalEngg             -1.0      -1.0      623.0
# ElectricalEngg             -1.0      -1.0      676.0
# TelecomEngg                -1.0      -1.0      548.0
# CivilEngg                  -1.0      -1.0      516.0
# conscientiousness           0.0       1.0        2.0
# agreeableness               0.0       1.0        2.0
# extraversion                0.0       1.0        3.0
# nueroticism                -0.0       1.0        3.0
# openess_to_experience      -0.0       1.0        2.0

# %% [markdown]
# ## Data Cleaning

# %%
df.nunique()
# Out:
# Salary                    177
# DOJ                        81
# DOL                        67
# Designation               419
# JobCity                   339
# Gender                      2
# DOB                      1872
# 10percentage              851
# 10board                   275
# 12graduation               16
# 12percentage              801
# 12board                   340
# CollegeID                1350
# CollegeTier                 2
# Degree                      4
# Specialization             46
# collegeGPA               1282
# CollegeCityID            1350
# CollegeCityTier             2
# CollegeState               26
# GraduationYear             11
# English                   111
# Logical                   107
# Quant                     138
# Domain                    243
# ComputerProgramming        79
# ElectronicsAndSemicon      29
# ComputerScience            20
# MechanicalEngg             42
# ElectricalEngg             31
# TelecomEngg                26
# CivilEngg                  23
# conscientiousness         141
# agreeableness             149
# extraversion              154
# nueroticism               217
# openess_to_experience     142
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Salary                   0
# DOJ                      0
# DOL                      0
# Designation              0
# JobCity                  0
# Gender                   0
# DOB                      0
# 10percentage             0
# 10board                  0
# 12graduation             0
# 12percentage             0
# 12board                  0
# CollegeID                0
# CollegeTier              0
# Degree                   0
# Specialization           0
# collegeGPA               0
# CollegeCityID            0
# CollegeCityTier          0
# CollegeState             0
# GraduationYear           0
# English                  0
# Logical                  0
# Quant                    0
# Domain                   0
# ComputerProgramming      0
# ElectronicsAndSemicon    0
# ComputerScience          0
# MechanicalEngg           0
# ElectricalEngg           0
# TelecomEngg              0
# CivilEngg                0
# conscientiousness        0
# agreeableness            0
# extraversion             0
# nueroticism              0
# openess_to_experience    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Salary                 3998 non-null   int64
#  1   DOJ                    3998 non-null   datetime64[ns]
#  2   DOL                    3998 non-null   object
#  3   Designation            3998 non-null   object
#  4   JobCity                3998 non-null   object
#  5   Gender                 3998 non-null   object
#  6   DOB                    3998 non-null   datetime64[ns]
#  7   10percentage           3998 non-null   float64
#  8   10board                3998 non-null   object
#  9   12graduation           3998 non-null   int64
#  10  12percentage           3998 non-null   float64
#  11  12board                3998 non-null   object
#  12  CollegeID              3998 non-null   int64
#  13  CollegeTier            3998 non-null   int64
#  14  Degree                 3998 non-null   object
#  15  Specialization         3998 non-null   object
#  16  collegeGPA             3998 non-null   float64
#  17  CollegeCityID          3998 non-null   int64
#  18  CollegeCityTier        3998 non-null   int64
#  19  CollegeState           3998 non-null   object
#  20  GraduationYear         3998 non-null   int64
#  21  English                3998 non-null   int64
#  22  Logical                3998 non-null   int64
#  23  Quant                  3998 non-null   int64
#  24  Domain                 3998 non-null   float64
#  25  ComputerProgramming    3998 non-null   int64
#  26  ElectronicsAndSemicon  3998 non-null   int64
#  27  ComputerScience        3998 non-null   int64
#  28  MechanicalEngg         3998 non-null   int64
#  29  ElectricalEngg         3998 non-null   int64
#  30  TelecomEngg            3998 non-null   int64
#  31  CivilEngg              3998 non-null   int64
#  32  conscientiousness      3998 non-null   float64
#  33  agreeableness          3998 non-null   float64
#  34  extraversion           3998 non-null   float64
#  35  nueroticism            3998 non-null   float64
#  36  openess_to_experience  3998 non-null   float64
# dtypes: datetime64[ns](2), float64(9), int64(17), object(9)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
df.drop(columns=['CollegeCityID','CollegeID'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityTier', 'CollegeState', 'GraduationYear', 'English',
#        'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %% [markdown]
# ## Univariate Analysis

# %%
df.columns
# Out:
# Index(['Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityTier', 'CollegeState', 'GraduationYear', 'English',
#        'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %% [markdown]
# ## Salary

# %%
df['Salary'].nunique()
# Out:
# 177

# %%
df['Salary'].plot(kind='kde')
plt.show()

# %%
df['Salary'].plot(kind='box')
plt.show()

# %%
df['Salary'].shape
# Out:
# (3998,)

# %%
indexNames = df[ df['Salary'] > 1000000 ].index
 
# Delete these row indexes from dfFrame
df.drop(indexNames , inplace=True)

# %%
df['Salary'].shape
# Out:
# (3962,)

# %% [markdown]
# ## DOJ

# %%
YOJ = df.DOJ.dt.year
MOJ = df.DOJ.dt.month_name()

# %%
df['YOJ'] = YOJ
df['MOJ'] = MOJ

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=YOJ)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=MOJ)
plt.show()

# %% [markdown]
# ## DOL

# %%
import datetime as dt
df["DOL"].replace("present",dt.datetime.today(),inplace=True)
df['DOL'] = pd.to_datetime(df['DOL']).dt.date

## Converting feature from DOJ and DOL as we are only concerned with how many years the person has worked in the organisation.
df['Period'] = pd.to_datetime(df["DOL"]).dt.year - pd.to_datetime(df['DOJ']).dt.year

# %%
df['DOL'] = pd.to_datetime(df['DOL'],errors='coerce')

# %%
YOL = df.DOL.dt.year
MOL = df.DOL.dt.month_name()

# %%
df['YOL'] = YOL
df['MOL'] = MOL

# %%
df.columns
# Out:
# Index(['Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityTier', 'CollegeState', 'GraduationYear', 'English',
#        'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism', 'openess_to_experience',
#        'YOJ', 'MOJ', 'Period', 'YOL', 'MOL'],
#       dtype='object')

# %%
df.head()
# Out:
#    Salary        DOJ        DOL              Designation    JobCity Gender  \
# 0  420000 2012-06-01 2023-04-19  senior quality engineer  Bangalore      f
# 1  500000 2013-09-01 2023-04-19        assistant manager     Indore      m
# 2  325000 2014-06-01 2023-04-19         systems engineer    Chennai      f
# 4  200000 2014-03-01 2015-03-01                      get    Manesar      m
# 5  300000 2014-06-01 2023-04-19          system engineer  Hyderabad      m
#
#          DOB  10percentage                         10board  12graduation  \
# 0 1990-02-19         84.30  board ofsecondary education,ap          2007
# 1 1989-10-04         85.40                            cbse          2007
# 2 1992-08-03         85.00                            cbse          2010
# 4 1991-02-27         78.00                            cbse          2008
# 5 1992-07-02         89.92                     state board          2010
#
#    12percentage                             12board  CollegeTier       Degree  \
# 0          95.8  board of intermediate education,ap            2  B.Tech/B.E.
# 1          85.0                                cbse            2  B.Tech/B.E.
# 2          68.2                                cbse            2  B.Tech/B.E.
# 4          76.8                                cbse            2  B.Tech/B.E.
# 5          87.0                         state board            2  B.Tech/B.E.
#
#                               Specialization  collegeGPA  CollegeCityTier  \
# 0                       computer engineering       78.00                0
# 1  electronics and communication engineering       70.06                0
# 2                     information technology       70.00                0
# 4  electronics and communication engineering       73.90                0
# 5  electronics and communication engineering       76.32                0
#
#      CollegeState  GraduationYear  English  Logical  Quant    Domain  \
# 0  Andhra Pradesh            2011      515      585    525  0.635979
# 1  Madhya Pradesh            2012      695      610    780  0.960603
# 2   Uttar Pradesh            2014      615      545    370  0.450877
# 4   Uttar Pradesh            2012      545      625    465  0.124502
# 5       Karnataka            2014      560      555    620 -1.000000
#
#    ComputerProgramming  ElectronicsAndSemicon  ComputerScience  \
# 0                  445                     -1               -1
# 1                   -1                    466               -1
# 2                  395                     -1               -1
# 4                   -1                    233               -1
# 5                  645                     -1              407
#
#    MechanicalEngg  ElectricalEngg  TelecomEngg  CivilEngg  conscientiousness  \
# 0              -1              -1           -1         -1             0.9737
# 1              -1              -1           -1         -1            -0.7335
# 2              -1              -1           -1         -1             0.2718
# 4              -1              -1           -1         -1            -0.8810
# 5              -1              -1           -1         -1            -0.3027
#
#    agreeableness  extraversion  nueroticism  openess_to_experience   YOJ  \
# 0         0.8128        0.5269      1.35490                -0.4455  2012
# 1         0.3789        1.2396     -0.10760                 0.8637  2013
# 2         1.7109        0.1637     -0.86820                 0.6721  2014
# 4        -0.2793       -1.0697      0.09163                -0.1295  2014
# 5        -0.6201       -2.2954     -0.74150                -0.8608  2014
#
#          MOJ  Period   YOL    MOL
# 0       June      11  2023  April
# 1  September      10  2023  April
# 2       June       9  2023  April
# 4      March       1  2015  March
# 5       June       9  2023  April

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=YOL)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=MOL)
plt.show()

# %% [markdown]
# ## JobCity

# %%
df['JobCity'] = df['JobCity'].str.replace('-1','Unknown')

# %%
# Get the value counts for each category in Designation column
value_counts = df['JobCity'].value_counts()

# Group the values with less than 30 counts as "Others"
other = value_counts[value_counts < 20].index.tolist()
df['JobCity'] = df['JobCity'].apply(lambda x: 'Others' if x in other else x)

# %%
df['JobCity'].value_counts()
# Out:
# Others           710
# Bangalore        619
# Noida            366
# Hyderabad        333
# Pune             288
# Chennai          272
# Gurgaon          196
# New Delhi        195
# Mumbai           107
# Kolkata           98
# Jaipur            46
# Mysore            36
# Lucknow           36
# Navi Mumbai       32
# chennai           27
# pune              26
# Chandigarh        26
# Greater Noida     25
# Indore            24
# Bhubaneswar       22
# Coimbatore        20
# Name: JobCity, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=df['JobCity'])
plt.show()

# %% [markdown]
# ## Gender

# %%
df['Gender'].value_counts()
# Out:
# m    3012
# f     950
# Name: Gender, dtype: int64

# %%
sns.countplot(df['Gender'])
plt.show()

# %% [markdown]
# ## DOB

# %%
Age = df.DOB.dt.year
Age = abs(Age - 2015)
df['Age'] = Age

# %%
sns.countplot(df['Age'])
plt.show()

# %%
df['Age'].plot(kind='kde')
plt.show()

# %% [markdown]
# ## 12graduation

# %%
df['12graduation'].value_counts()
# Out:
# 2009    1047
# 2008     932
# 2010     739
# 2007     522
# 2006     401
# 2005     155
# 2004      68
# 2011      44
# 2003      24
# 2002      14
# 2012      10
# 2001       2
# 1995       1
# 1998       1
# 2013       1
# 1999       1
# Name: 12graduation, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['12graduation'])
plt.show()

# %% [markdown]
# ## Specialization

# %%
df.Specialization = df.Specialization.str.replace('computer engineering' ,'computers')
df.Specialization = df.Specialization.str.replace('information technology' ,'computers')
df.Specialization = df.Specialization.str.replace('computer science & engineering' ,'computers')
df.Specialization = df.Specialization.str.replace('computer application' ,'computers')
df.Specialization = df.Specialization.str.replace('electronics and computer engineering' ,'computers')
df.Specialization = df.Specialization.str.replace('information technology' ,'computers')
df.Specialization = df.Specialization.str.replace('information science engineering' ,'computers')
df.Specialization = df.Specialization.str.replace('computer science and technology' ,'computers')
df.Specialization = df.Specialization.str.replace('computer and communication engineering' ,'computers')
df.Specialization = df.Specialization.str.replace('information & communication technology' ,'computers')
df.Specialization = df.Specialization.str.replace('information science' ,'computers')
df.Specialization = df.Specialization.str.replace('computer networking' ,'computers')
df.Specialization = df.Specialization.str.replace('computer science' ,'computers')

df.Specialization = df.Specialization.str.replace('electronics and communication engineering' ,'etrx')
df.Specialization = df.Specialization.str.replace('electronics and electrical engineering' ,'etrx')
df.Specialization = df.Specialization.str.replace('electronics & telecommunications' ,'etrx')
df.Specialization = df.Specialization.str.replace('electrical engineering' ,'etrx')
df.Specialization = df.Specialization.str.replace('applied electronics and instrumentation' ,'etrx')
df.Specialization = df.Specialization.str.replace('electronics & instrumentation eng' ,'etrx')
df.Specialization = df.Specialization.str.replace('electronics and instrumentation engineering' ,'etrx')
df.Specialization = df.Specialization.str.replace('electronics engineering' ,'etrx')
df.Specialization = df.Specialization.str.replace('embedded systems technology' ,'etrx')
df.Specialization = df.Specialization.str.replace('electrical and power engineering' ,'etrx')
df.Specialization = df.Specialization.str.replace('mechatronics' ,'etrx')
df.Specialization = df.Specialization.str.replace('telecommunication engineering','etrx')
df.Specialization = df.Specialization.str.replace('electronics' ,'etrx')

df.Specialization = df.Specialization.str.replace('mechanical engineering','mech')
df.Specialization = df.Specialization.str.replace('mechanical and automation','mech')
df.Specialization = df.Specialization.str.replace('metallurgical engineering','mech')
df.Specialization = df.Specialization.str.replace('ceramic engineering','mech')
df.Specialization = df.Specialization.str.replace('mechatronics','mech')
df.Specialization = df.Specialization.str.replace('mechanical & production engineering','mech')
df.Specialization = df.Specialization.str.replace('internal combustion engine','mech')
df.Specialization = df.Specialization.str.replace('industrial & production engineering','mech')
df.Specialization = df.Specialization.str.replace('automobile/automotive engineering','mech')
df.Specialization = df.Specialization.str.replace('industrial engineering','mech')
df.Specialization = df.Specialization.str.replace('power systems and automation','mech')
df.Specialization = df.Specialization.str.replace('industrial & management engineering','mech')

df.Specialization = df.Specialization.str.replace('control and instrumentation engineering','instrumentation engineering')
df.Specialization = df.Specialization.str.replace('polymer technology','chemical engineering')
df.Specialization = df.Specialization.str.replace('etrx and computers' ,'etrx')

# %%
df['Specialization'].value_counts()
# Out:
# computers                                  2267
# etrx                                       1373
# mech                                        226
# civil engineering                            29
# instrumentation and control engineering      19
# biotechnology                                15
# other                                        13
# chemical engineering                         10
# instrumentation engineering                   5
# aeronautical engineering                      3
# biomedical engineering                        2
# Name: Specialization, dtype: int64

# %%
sns.countplot(y = df['Specialization'])
plt.show()

# %% [markdown]
# ## College State

# %%
df['CollegeState'].value_counts()
# Out:
# Uttar Pradesh        905
# Karnataka            369
# Tamil Nadu           363
# Telangana            316
# Maharashtra          260
# Andhra Pradesh       223
# West Bengal          195
# Punjab               190
# Madhya Pradesh       185
# Haryana              180
# Rajasthan            172
# Orissa               171
# Delhi                160
# Uttarakhand          113
# Kerala                33
# Jharkhand             28
# Chhattisgarh          27
# Gujarat               23
# Himachal Pradesh      16
# Bihar                 10
# Jammu and Kashmir      7
# Assam                  5
# Union Territory        5
# Sikkim                 3
# Meghalaya              2
# Goa                    1
# Name: CollegeState, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(y=df['CollegeState'])
plt.show()

# %%
df['GraduationYear'].value_counts()
# Out:
# 2013    1175
# 2014    1033
# 2012     843
# 2011     501
# 2010     278
# 2015      91
# 2009      24
# 2017       8
# 2016       7
# 0          1
# 2007       1
# Name: GraduationYear, dtype: int64

# %%
df.GraduationYear = df.GraduationYear.replace(0,2007)

# %%
plt.figure(figsize=(9,6))
sns.countplot(x = df['GraduationYear'])
plt.show()

# %% [markdown]
# ## Data Visualization

# %%
num_df = df.select_dtypes(include=['int64','float64'])
num_cols = num_df.columns
num_cols
# Out:
# Index(['Salary', '10percentage', '12graduation', '12percentage', 'CollegeTier',
#        'collegeGPA', 'CollegeCityTier', 'GraduationYear', 'English', 'Logical',
#        'Quant', 'Domain', 'ComputerProgramming', 'ElectronicsAndSemicon',
#        'ComputerScience', 'MechanicalEngg', 'ElectricalEngg', 'TelecomEngg',
#        'CivilEngg', 'conscientiousness', 'agreeableness', 'extraversion',
#        'nueroticism', 'openess_to_experience', 'YOJ', 'Period', 'YOL', 'Age'],
#       dtype='object')

# %%
cat_df = df.select_dtypes(include=['object'])
cat_cols = cat_df.columns
cat_cols
# Out:
# Index(['Designation', 'JobCity', 'Gender', '10board', '12board', 'Degree',
#        'Specialization', 'CollegeState', 'MOJ', 'MOL'],
#       dtype='object')

# %%
fig, axes = plt.subplots(nrows=13, ncols=2, figsize=(12,15))
for col, ax in zip(num_cols, axes.flatten()):
    sns.boxplot(x=df[col], ax=ax)
    ax.set_title(col)
plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=13, ncols=2, figsize=(12,15))
for col, ax in zip(num_cols, axes.flatten()):
    sns.histplot(x=df[col], ax=ax, kde=True)
    ax.set_title(col)
plt.tight_layout()

# %% [markdown]
# ## Bivariate Analysis

# %%
df.corr()
# Out:
#                          Salary  10percentage  12graduation  12percentage  \
# Salary                 1.000000      0.274463     -0.171369      0.261412
# 10percentage           0.274463      1.000000      0.268657      0.642909
# 12graduation          -0.171369      0.268657      1.000000      0.258391
# 12percentage           0.261412      0.642909      0.258391      1.000000
# CollegeTier           -0.210677     -0.119612      0.023885     -0.095467
# collegeGPA             0.192676      0.310853      0.088415      0.345918
# CollegeCityTier        0.034107      0.115435     -0.003528      0.128771
# GraduationYear        -0.256373      0.092149      0.788590      0.056822
# English                0.250266      0.347753      0.152293      0.212230
# Logical                0.243455      0.313364      0.108773      0.241747
# Quant                  0.350994      0.315694      0.005072      0.313087
# Domain                 0.157611      0.076545     -0.034710      0.071133
# ComputerProgramming    0.155081      0.051441     -0.047694      0.079292
# ElectronicsAndSemicon  0.011617      0.082217     -0.004409      0.116645
# ComputerScience       -0.136872     -0.020713      0.289470     -0.045492
# MechanicalEngg         0.027289      0.056381      0.039656      0.041199
# ElectricalEngg        -0.052905      0.074845      0.123696      0.064197
# TelecomEngg           -0.021664      0.048993      0.022383      0.044922
# CivilEngg              0.066377      0.030168     -0.005461      0.005892
# conscientiousness     -0.064134      0.067968      0.103158      0.056852
# agreeableness          0.060564      0.135238      0.042380      0.102070
# extraversion          -0.025842     -0.004738      0.061861     -0.007827
# nueroticism           -0.057979     -0.131504     -0.080266     -0.093825
# openess_to_experience -0.011443      0.036451     -0.015736      0.005164
# YOJ                   -0.263285      0.059792      0.691602      0.021022
# Period                 0.385774      0.145729      0.023606      0.137184
# YOL                    0.294298      0.158392      0.227854      0.138650
# Age                    0.162958     -0.242263     -0.871706     -0.265461
#
#                        CollegeTier  collegeGPA  CollegeCityTier  \
# Salary                   -0.210677    0.192676         0.034107
# 10percentage             -0.119612    0.310853         0.115435
# 12graduation              0.023885    0.088415        -0.003528
# 12percentage             -0.095467    0.345918         0.128771
# CollegeTier               1.000000   -0.078781        -0.101351
# collegeGPA               -0.078781    1.000000         0.019564
# CollegeCityTier          -0.101351    0.019564         1.000000
# GraduationYear           -0.031960    0.084829        -0.052220
# English                  -0.179965    0.103180         0.050172
# Logical                  -0.175201    0.196229         0.018797
# Quant                    -0.245079    0.213676         0.006216
# Domain                   -0.056445    0.104624         0.006825
# ComputerProgramming      -0.069388    0.137988         0.060695
# ElectronicsAndSemicon    -0.028529    0.025616         0.041952
# ComputerScience           0.001542    0.008233        -0.011217
# MechanicalEngg           -0.020902   -0.030655        -0.050674
# ElectricalEngg            0.001206    0.052963         0.010268
# TelecomEngg              -0.002775   -0.002905         0.051364
# CivilEngg                -0.034992   -0.018880        -0.033584
# conscientiousness         0.057750    0.069929         0.013176
# agreeableness            -0.033503    0.066884         0.004457
# extraversion              0.011262   -0.031928        -0.008941
# nueroticism               0.016457   -0.072104         0.005124
# openess_to_experience    -0.018207    0.026841        -0.018236
# YOJ                       0.024833    0.044015        -0.044926
# Period                   -0.038804    0.108091         0.014135
# YOL                      -0.030092    0.117385         0.000323
# Age                      -0.039771   -0.114182         0.036359
#
#                        GraduationYear   English   Logical     Quant    Domain  \
# Salary                      -0.256373  0.250266  0.243455  0.350994  0.157611
# 10percentage                 0.092149  0.347753  0.313364  0.315694  0.076545
# 12graduation                 0.788590  0.152293  0.108773  0.005072 -0.034710
# 12percentage                 0.056822  0.212230  0.241747  0.313087  0.071133
# CollegeTier                 -0.031960 -0.179965 -0.175201 -0.245079 -0.056445
# collegeGPA                   0.084829  0.103180  0.196229  0.213676  0.104624
# CollegeCityTier             -0.052220  0.050172  0.018797  0.006216  0.006825
# GraduationYear               1.000000  0.123019  0.095904 -0.003193 -0.034402
# English                      0.123019  1.000000  0.441710  0.371658  0.090317
# Logical                      0.095904  0.441710  1.000000  0.499386  0.168616
# Quant                       -0.003193  0.371658  0.499386  1.000000  0.207728
# Domain                      -0.034402  0.090317  0.168616  0.207728  1.000000
# ComputerProgramming         -0.010232  0.124307  0.183162  0.145298  0.305890
# ElectronicsAndSemicon       -0.081338  0.015493 -0.013077  0.099909  0.089699
# ComputerScience              0.379663  0.062876  0.046306 -0.041063  0.058857
# MechanicalEngg               0.032828  0.001263 -0.008306  0.020583  0.049358
# ElectricalEngg               0.129966  0.032908  0.012436  0.021335  0.043277
# TelecomEngg                 -0.016562 -0.004338 -0.010851  0.023750  0.025504
# CivilEngg                    0.002048 -0.007633 -0.011191  0.000628  0.017751
# conscientiousness            0.112184  0.033940  0.026269 -0.006162 -0.039121
# agreeableness                0.025702  0.191989  0.164581  0.101010  0.051368
# extraversion                 0.083437  0.019291 -0.009344 -0.029785 -0.023580
# nueroticism                 -0.087997 -0.153243 -0.176974 -0.129941 -0.016731
# openess_to_experience       -0.009942  0.067468  0.046459  0.018852  0.009235
# YOJ                          0.786706  0.074080  0.044095 -0.051333 -0.068818
# Period                      -0.019620  0.097053  0.104037  0.140761  0.057929
# YOL                          0.214329  0.115645  0.113495  0.120648  0.035511
# Age                         -0.740041 -0.104494 -0.100706 -0.035884  0.040954
#
#                        ComputerProgramming  ElectronicsAndSemicon  \
# Salary                            0.155081               0.011617
# 10percentage                      0.051441               0.082217
# 12graduation                     -0.047694              -0.004409
# 12percentage                      0.079292               0.116645
# CollegeTier                      -0.069388              -0.028529
# collegeGPA                        0.137988               0.025616
# CollegeCityTier                   0.060695               0.041952
# GraduationYear                   -0.010232              -0.081338
# English                           0.124307               0.015493
# Logical                           0.183162              -0.013077
# Quant                             0.145298               0.099909
# Domain                            0.305890               0.089699
# ComputerProgramming               1.000000              -0.370955
# ElectronicsAndSemicon            -0.370955               1.000000
# ComputerScience                   0.254982              -0.273960
# MechanicalEngg                   -0.284240              -0.108482
# ElectricalEngg                   -0.138679               0.037121
# TelecomEngg                      -0.249148               0.387849
# CivilEngg                        -0.088560               0.002860
# conscientiousness                 0.011413              -0.024468
# agreeableness                     0.074991              -0.025878
# extraversion                      0.044213              -0.045199
# nueroticism                      -0.082081               0.020600
# openess_to_experience             0.043622              -0.015953
# YOJ                              -0.047230              -0.049985
# Period                            0.039090               0.007630
# YOL                               0.023727              -0.007456
# Age                               0.043549               0.021646
#
#                        ComputerScience  MechanicalEngg  ElectricalEngg  \
# Salary                       -0.136872        0.027289       -0.052905
# 10percentage                 -0.020713        0.056381        0.074845
# 12graduation                  0.289470        0.039656        0.123696
# 12percentage                 -0.045492        0.041199        0.064197
# CollegeTier                   0.001542       -0.020902        0.001206
# collegeGPA                    0.008233       -0.030655        0.052963
# CollegeCityTier              -0.011217       -0.050674        0.010268
# GraduationYear                0.379663        0.032828        0.129966
# English                       0.062876        0.001263        0.032908
# Logical                       0.046306       -0.008306        0.012436
# Quant                        -0.041063        0.020583        0.021335
# Domain                        0.058857        0.049358        0.043277
# ComputerProgramming           0.254982       -0.284240       -0.138679
# ElectronicsAndSemicon        -0.273960       -0.108482        0.037121
# ComputerScience               1.000000       -0.123980       -0.084358
# MechanicalEngg               -0.123980        1.000000       -0.040500
# ElectricalEngg               -0.084358       -0.040500        1.000000
# TelecomEngg                  -0.148526       -0.070730       -0.051844
# CivilEngg                    -0.052927        0.076832       -0.020246
# conscientiousness             0.089800       -0.010756        0.029621
# agreeableness                 0.039657       -0.026537       -0.015016
# extraversion                  0.101947       -0.018952        0.004916
# nueroticism                  -0.114433        0.037650       -0.031635
# openess_to_experience         0.058490       -0.029325       -0.012573
# YOJ                           0.347836        0.000010        0.109062
# Period                       -0.028070       -0.002405       -0.034177
# YOL                           0.076044       -0.002319       -0.000651
# Age                          -0.277337       -0.039187       -0.113065
#
#                        TelecomEngg  CivilEngg  conscientiousness  \
# Salary                   -0.021664   0.066377          -0.064134
# 10percentage              0.048993   0.030168           0.067968
# 12graduation              0.022383  -0.005461           0.103158
# 12percentage              0.044922   0.005892           0.056852
# CollegeTier              -0.002775  -0.034992           0.057750
# collegeGPA               -0.002905  -0.018880           0.069929
# CollegeCityTier           0.051364  -0.033584           0.013176
# GraduationYear           -0.016562   0.002048           0.112184
# English                  -0.004338  -0.007633           0.033940
# Logical                  -0.010851  -0.011191           0.026269
# Quant                     0.023750   0.000628          -0.006162
# Domain                    0.025504   0.017751          -0.039121
# ComputerProgramming      -0.249148  -0.088560           0.011413
# ElectronicsAndSemicon     0.387849   0.002860          -0.024468
# ComputerScience          -0.148526  -0.052927           0.089800
# MechanicalEngg           -0.070730   0.076832          -0.010756
# ElectricalEngg           -0.051844  -0.020246           0.029621
# TelecomEngg               1.000000  -0.031697          -0.002525
# CivilEngg                -0.031697   1.000000          -0.017815
# conscientiousness        -0.002525  -0.017815           1.000000
# agreeableness            -0.013353  -0.034159           0.482179
# extraversion             -0.039425  -0.031723           0.356268
# nueroticism               0.019848   0.010277          -0.330871
# openess_to_experience     0.000756  -0.031293           0.395499
# YOJ                       0.015396  -0.015981           0.112711
# Period                    0.022383   0.013417          -0.039756
# YOL                       0.026171   0.008212          -0.004954
# Age                      -0.010941   0.014018          -0.101531
#
#                        agreeableness  extraversion  nueroticism  \
# Salary                      0.060564     -0.025842    -0.057979
# 10percentage                0.135238     -0.004738    -0.131504
# 12graduation                0.042380      0.061861    -0.080266
# 12percentage                0.102070     -0.007827    -0.093825
# CollegeTier                -0.033503      0.011262     0.016457
# collegeGPA                  0.066884     -0.031928    -0.072104
# CollegeCityTier             0.004457     -0.008941     0.005124
# GraduationYear              0.025702      0.083437    -0.087997
# English                     0.191989      0.019291    -0.153243
# Logical                     0.164581     -0.009344    -0.176974
# Quant                       0.101010     -0.029785    -0.129941
# Domain                      0.051368     -0.023580    -0.016731
# ComputerProgramming         0.074991      0.044213    -0.082081
# ElectronicsAndSemicon      -0.025878     -0.045199     0.020600
# ComputerScience             0.039657      0.101947    -0.114433
# MechanicalEngg             -0.026537     -0.018952     0.037650
# ElectricalEngg             -0.015016      0.004916    -0.031635
# TelecomEngg                -0.013353     -0.039425     0.019848
# CivilEngg                  -0.034159     -0.031723     0.010277
# conscientiousness           0.482179      0.356268    -0.330871
# agreeableness               1.000000      0.455013    -0.206203
# extraversion                0.455013      1.000000    -0.096258
# nueroticism                -0.206203     -0.096258     1.000000
# openess_to_experience       0.592190      0.435520    -0.065742
# YOJ                         0.030019      0.084487    -0.067313
# Period                      0.012396     -0.010736    -0.028410
# YOL                         0.020866      0.014688    -0.047382
# Age                        -0.025241     -0.055480     0.082976
#
#                        openess_to_experience       YOJ    Period       YOL  \
# Salary                             -0.011443 -0.263285  0.385774  0.294298
# 10percentage                        0.036451  0.059792  0.145729  0.158392
# 12graduation                       -0.015736  0.691602  0.023606  0.227854
# 12percentage                        0.005164  0.021022  0.137184  0.138650
# CollegeTier                        -0.018207  0.024833 -0.038804 -0.030092
# collegeGPA                          0.026841  0.044015  0.108091  0.117385
# CollegeCityTier                    -0.018236 -0.044926  0.014135  0.000323
# GraduationYear                     -0.009942  0.786706 -0.019620  0.214329
# English                             0.067468  0.074080  0.097053  0.115645
# Logical                             0.046459  0.044095  0.104037  0.113495
# Quant                               0.018852 -0.051333  0.140761  0.120648
# Domain                              0.009235 -0.068818  0.057929  0.035511
# ComputerProgramming                 0.043622 -0.047230  0.039090  0.023727
# ElectronicsAndSemicon              -0.015953 -0.049985  0.007630 -0.007456
# ComputerScience                     0.058490  0.347836 -0.028070  0.076044
# MechanicalEngg                     -0.029325  0.000010 -0.002405 -0.002319
# ElectricalEngg                     -0.012573  0.109062 -0.034177 -0.000651
# TelecomEngg                         0.000756  0.015396  0.022383  0.026171
# CivilEngg                          -0.031293 -0.015981  0.013417  0.008212
# conscientiousness                   0.395499  0.112711 -0.039756 -0.004954
# agreeableness                       0.592190  0.030019  0.012396  0.020866
# extraversion                        0.435520  0.084487 -0.010736  0.014688
# nueroticism                        -0.065742 -0.067313 -0.028410 -0.047382
# openess_to_experience               1.000000 -0.004504 -0.029233 -0.029553
# YOJ                                -0.004504  1.000000 -0.034260  0.263443
# Period                             -0.029233 -0.034260  1.000000  0.955083
# YOL                                -0.029553  0.263443  0.955083  1.000000
# Age                                 0.011462 -0.643567 -0.020862 -0.210962
#
#                             Age
# Salary                 0.162958
# 10percentage          -0.242263
# 12graduation          -0.871706
# 12percentage          -0.265461
# CollegeTier           -0.039771
# collegeGPA            -0.114182
# CollegeCityTier        0.036359
# GraduationYear        -0.740041
# English               -0.104494
# Logical               -0.100706
# Quant                 -0.035884
# Domain                 0.040954
# ComputerProgramming    0.043549
# ElectronicsAndSemicon  0.021646
# ComputerScience       -0.277337
# MechanicalEngg        -0.039187
# ElectricalEngg        -0.113065
# TelecomEngg           -0.010941
# CivilEngg              0.014018
# conscientiousness     -0.101531
# agreeableness         -0.025241
# extraversion          -0.055480
# nueroticism            0.082976
# openess_to_experience  0.011462
# YOJ                   -0.643567
# Period                -0.020862
# YOL                   -0.210962
# Age                    1.000000

# %%
sns.set(style="white")
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')

# Show the plot
plt.show()

# %%
plt.scatter(num_df['English'], num_df['Salary'])
plt.title('English Scores vs. Salary')
plt.xlabel('English Scores')
plt.ylabel('Salary')
plt.show()

# %%
plt.figure(figsize=(9,5))
sns.scatterplot(x='10percentage', y='Salary', data=df)
plt.title('10percentage Vs Salary')
plt.show()

# %%
plt.figure(figsize=(9,5))
sns.scatterplot(x='12percentage', y='Salary', data=df)
plt.title('12percentage Vs Salary')
plt.show()

# %%
plt.figure(figsize=(9,5))
plt.title('Period Vs Salary')
sns.barplot(x='Period',y='Salary',data=df)
plt.show()

# %%
plt.figure(figsize=(9,5))
plt.title('Age Vs Salary')
sns.barplot(x='Age',y='Salary',data=df)
# Out:
# <AxesSubplot:title={'center':'Age Vs Salary'}, xlabel='Age', ylabel='Salary'>

# %%
plt.figure(figsize=(12,4))
plt.title("Boxplot of Gender vs Salary")
sns.boxplot(data = df, x = 'Salary', y='Gender' );

# %%
plt.figure(figsize=(9,6))
sns.catplot(x="CollegeTier", hue="Gender", kind="count", data=df)
plt.title("CollegeTier VS Gender")
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.catplot(x="Degree", y="Salary", kind="bar", data=df)
plt.title("Degree VS Salary")
plt.show()

# %%
plt.figure(figsize=(9,5))
plt.title("Count of Employee Specialization")
df['Specialization'].value_counts().head(25).plot.bar()
# Out:
# <AxesSubplot:title={'center':'Count of Employee Specialization'}>

# %%
fig, ax = plt.subplots(figsize=(12,6))
plt.title("Specialization vs Salary")
sns.barplot(data=df, x = 'Specialization', y='Salary')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %%
plt.figure(figsize=(9,6))
sns.boxplot(data=df, x='GraduationYear', y='Salary')
plt.title("Graduation VS Salary")
plt.show()

# %%
sns.catplot(y="CollegeState", x="Salary", kind="bar", data=df)
plt.title("CollegeState VS Salary")
plt.show()

# %%
# Create a pairplot
sns.pairplot(df, vars=["Quant", "English", "Logical"], diag_kind="kde", hue ="Gender")


# Show the plot
plt.show()

# %% [markdown]
# ## Research Questions
#
# 1. Times of India article dated Jan 18, 2019 states that “After doing your Computer Science
# Engineering if you take up jobs as a Programming Analyst, Software Engineer,
# Hardware Engineer and Associate Engineer you can earn up to 2.5-3 lakhs as a fresh
# graduate.”
#    Test this claim with the data given to you.
#
# 2. Is there a relationship between gender and specialisation? (i.e. Does the preference of
# Specialisation depend on the Gender?)

# %% [markdown]
# ## Research Question No : 1
#
# Is there a relationship between gender and specialisation? (i.e. Does the preference of Specialisation depend on the Gender?)

# %%
df['Gender'].value_counts()
# Out:
# m    3012
# f     950
# Name: Gender, dtype: int64

# %%
df.groupby(df['Gender']).count()['Specialization']
# Out:
# Gender
# f     950
# m    3012
# Name: Specialization, dtype: int64

# %%
plt.figure(figsize=(9,6))
sns.catplot(x="Gender", hue="Specialization", kind="count", data=df)
plt.title("Specialization VS Gender")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))
sns.countplot(data=df, x='Specialization', hue='Gender')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %%
# Calculating the frequency distribution of each specialization based on gender

freq_table = pd.crosstab(df['Gender'], df['Specialization'], margins=True)
freq_table.div(freq_table['All'], axis=0)
# Out:
# Specialization  aeronautical engineering  biomedical engineering  \
# Gender
# f                               0.001053                0.002105
# m                               0.000664                0.000000
# All                             0.000757                0.000505
#
# Specialization  biotechnology  chemical engineering  civil engineering  \
# Gender
# f                    0.009474              0.001053           0.006316
# m                    0.001992              0.002988           0.007636
# All                  0.003786              0.002524           0.007320
#
# Specialization  computers      etrx  instrumentation and control engineering  \
# Gender
# f                0.629474  0.327368                                 0.009474
# m                0.554117  0.352590                                 0.003320
# All              0.572186  0.346542                                 0.004796
#
# Specialization  instrumentation engineering      mech     other  All
# Gender
# f                                  0.000000  0.013684  0.000000  1.0
# m                                  0.001660  0.070717  0.004316  1.0
# All                                0.001262  0.057042  0.003281  1.0

# %% [markdown]
# **Observation**
#
#
# - The most popular specializations for both males and females are Computer Science and Electronics and Telecommunications (ETRX), which make up more than 60% and 55% of their respective proportions.
#
# - The proportion of females in Aeronautical Engineering, Biomedical Engineering, and Biotechnology is higher than the proportion of males in these fields.
#
# - The proportion of males in Chemical Engineering, Civil Engineering, and Mechanical Engineering is higher than the proportion of females in these fields.
#
# - Other specializations have a higher proportion of males than females.

# %% [markdown]
# ## Research Question 2

# %% [markdown]
# After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, Software Engineer, Hardware Engineer and Associate Engineer you can earn up to 2.5-3 lakhs as a fresh graduate. Test this claim with the data given to you.

# %%
rq = df[['Salary', 'Designation', 'Specialization', 'Gender']]

# %%
grouped_df = rq.groupby(['Designation', 'Specialization']).agg({'Salary': 'mean'}).reset_index()

lower_bound = 250000
upper_bound = 300000
result = (rq['Salary'] >= lower_bound) & (rq['Salary'] <= upper_bound)

if result.all():
    print("The claim is supported by the data.")
else:
    print("The claim is not supported by the data.")
# Out:
# The claim is not supported by the data.
